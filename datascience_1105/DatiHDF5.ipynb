# %%
import pandas as pd

# %%
dati = pd.read_hdf("dati/nsfg.hdf5")

# %%
type(dati)
# Out:
# pandas.core.frame.DataFrame

# %%
dati
# Out:
#       caseid  outcome  birthwgt_lb1  birthwgt_oz1  prglngth  nbrnaliv  agecon  \
# 0      60418        1           5.0           4.0        40       1.0    2000
# 1      60418        1           4.0          12.0        36       1.0    2291
# 2      60418        1           5.0           4.0        36       1.0    3241
# 3      60419        6           NaN           NaN        33       NaN    3650
# 4      60420        1           8.0          13.0        41       1.0    2191
# ...      ...      ...           ...           ...       ...       ...     ...
# 9353   70615        1           4.0          11.0        35       1.0    1758
# 9354   70616        1           8.0           7.0        42       1.0    1741
# 9355   70616        1           7.0           6.0        36       1.0    2091
# 9356   70619        1           8.0           3.0        41       1.0    3450
# 9357   70619        1           8.0           5.0        40       1.0    3683
#
# ...

# %%
dati.iloc[:100, 3:8]
# Out:
#     birthwgt_oz1  prglngth  nbrnaliv  agecon  agepreg
# 0            4.0        40       1.0    2000   2075.0
# 1           12.0        36       1.0    2291   2358.0
# 2            4.0        36       1.0    3241   3308.0
# 3            NaN        33       NaN    3650      NaN
# 4           13.0        41       1.0    2191   2266.0
# ..           ...       ...       ...     ...      ...
# 95           NaN         2       NaN    3366   3366.0
# 96           NaN        12       NaN    1825   1841.0
# 97           9.0        40       1.0    1883   1958.0
# 98           8.0        40       1.0    2391   2466.0
# 99           9.0        40       1.0    2216   2291.0
#
# [100 rows x 5 columns]
