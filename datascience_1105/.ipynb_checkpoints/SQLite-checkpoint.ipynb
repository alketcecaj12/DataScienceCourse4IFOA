# %%
import sqlite3

# %%
conn = sqlite3.connect('test3.db')
print("Database initiated successfully")
# Out:
# Database initiated successfully

# %%
conn.execute('''CREATE TABLE COMPANY
                (ID INT PRIMARY KEY     NOT NULL,
                NAME           TEXT    NOT NULL,
                AGE            INT     NOT NULL,
                ADDRESS        CHAR(50),
                SALARY         REAL )''')
print("Table created successfully")
# Out:
# Table created successfully

# %%
# close the connection
conn.close()

# %% [markdown]
# ### Insert data in table

# %%
conn = sqlite3.connect('test3.db')

conn.execute("INSERT INTO COMPANY (ID,NAME,AGE,ADDRESS,SALARY) \
      VALUES (1, 'Alket', 44, 'Denmark', 20000.00 )");

conn.execute("INSERT INTO COMPANY (ID,NAME,AGE,ADDRESS,SALARY) \
      VALUES (2, 'Sasha', 23, 'California', 25000.00 )");


conn.commit()

conn.close()

# %% [markdown]
# ### Fetch the data

# %%
conn = sqlite3.connect('test3.db')

cursor = conn.execute("SELECT * from COMPANY")

for row in cursor:
    print(row)
# Out:
# (1, 'Alket', 44, 'Denmark', 20000.0)
# (2, 'Sasha', 23, 'California', 25000.0)

# %%
conn.close()
