# %%
import pandas as pd

# %%
url = "dati/simple_json.json"

# %%
data = pd.read_json(url)

# %%
data
# Out:
#    id   name  math  physics  chemistry
# 0   1  Alket    90       95         81
# 1   2  Sasha    99       87         91
# 2   3  Jenny    89       90         98
