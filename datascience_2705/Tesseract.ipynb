# %%
import cv2
import pytesseract
import matplotlib.pyplot as plt

# %%
img = cv2.imread("ArtStampa.png")
plt.imshow(img)

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:/Program Files/Tesseract-OCR/tesseract.exe"

# %%
testo_img = pytesseract.image_to_string(img)

# %%
testo_img = testo_img.replace("\x0c", "")

# %%
str_list = testo_img.split("\n")

# %%
str_list
# Out:
# ['Carla Fracci é morta. La signora della danza italiana stava male da',
#  'diversi giorni ma, a quanto si apprende, lei stessa voleva mantenere',
#  'uno stretto riserbo sulle sue condizioni di salute.',
#  '',
#  'La camera ardente sara allestita nel foyer del teatro alla Scala di',
#  'Milano, domani dalle 10.30 alle 18. «Faremo una cosa che é stata',
#  'fatta pochissime volte» ha annunciato il sovrintendente Dominique',
#  'Meyer. «Cosa rara ma trattandosi di Carla Fracci...» ha aggiunto',
#  'sottolineando che «é stata la ballerina pit importante del teatro',
#  "dell'ultimo secolo ma anche una stella importantissima nella danza",
#  'internazionale».',
#  '']
