# %%
import numpy as np

# %%
a = np.array([1, 2, 3, 4, 5, 6, 7, 10])

# %%
a.shape
# Out:
# (8,)

# %%
a.ndim
# Out:
# 1

# %%
a.size
# Out:
# 8

# %%
b = np.array([[2, 3, 4, 5,  6,  7],
              [3, 6, 7, 8, 10, 11]])

# %%
b.ndim
# Out:
# 2

# %%
b.size
# Out:
# 12

# %%
b.shape
# Out:
# (2, 6)

# %%
c = np.array([[[1, 2, 3],
               [3, 4, 5],
               [7, 8, 11] ],
             [[1, 2, 3],
               [3, 4, 5],
               [7, 8, 11] ],
             [[1, 2, 3],
               [3, 4, 5],
               [7, 8, 11] ],])

# %%
c.size
# Out:
# 27

# %%
c.shape
# Out:
# (3, 3, 3)

# %%
c.ndim
# Out:
# 3

# %%
a
# Out:
# array([ 1,  2,  3,  4,  5,  6,  7, 10])

# %%
a[2:]
# Out:
# array([ 3,  4,  5,  6,  7, 10])

# %%
a[0:2]
# Out:
# array([1, 2])
