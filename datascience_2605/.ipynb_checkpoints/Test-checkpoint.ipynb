# %%
import pandas as pd
import numpy as np

# %%
a = np.array([1, 2, 3, 4, 5, 6, 8])

# %%
np.mean(a)
# Out:
# 4.142857142857143

# %%
np.median(a)
# Out:
# 4.0

# %%
np.std(a)
# Out:
# 2.231499907401901

# %%
b = np.array([1, 2, 3, 4, 5, 6, 8, 100])

# %%
np.median(b)
# Out:
# 4.5

# %%
np.mean(b)
# Out:
# 16.125

# %%
np.std(b)
# Out:
# 31.77041666393439

# %%
z = (a - np.mean(a)) / np.std(a)

# %%
z
# Out:
# array([-1.40840568, -0.9602766 , -0.51214752, -0.06401844,  0.38411064,
#         0.83223972,  1.72849788])
