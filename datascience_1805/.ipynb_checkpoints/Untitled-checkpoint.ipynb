# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
s = pd.Series([1, 2, 3, 4, 5, 6, 7,  10, 50])

# %%
s.quantile(0.25)
# Out:
# 3.0

# %%
plt.figure(figsize = (20, 2))
plt.boxplot(s, vert = False)
plt.show()
