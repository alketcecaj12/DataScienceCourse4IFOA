# %%
import numpy as np
from sklearn.neighbors import LocalOutlierFactor

X = [[-1.1, 0.2], [0.2, 1.2], [101.1, 56.3], [0.3, 1.4], [1.9, 1.89], [0.8, 1.9], [125.1, 70.3]]
print(X)

clf = LocalOutlierFactor(n_neighbors=3)
clf.fit_predict(X)

outliers = clf.negative_outlier_factor_
# Out:
# [[-1.1, 0.2], [0.2, 1.2], [101.1, 56.3], [0.3, 1.4], [1.9, 1.89], [0.8, 1.9], [125.1, 70.3]]
